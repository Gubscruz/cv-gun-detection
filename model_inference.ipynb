# %%
# %pip install -U inference-sdk
# Out:
# Collecting inference-sdk
#   Downloading inference_sdk-1.2.6-py3-none-any.whl.metadata (20 kB)
# Collecting requests<3.0.0,>=2.32.0 (from inference-sdk)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting dataclasses-json~=0.6.0 (from inference-sdk)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting opencv-python<=4.10.0.84,>=4.8.1.78 (from inference-sdk)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting pillow<12.0,>=11.0 (from inference-sdk)
#   Downloading pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting supervision>=0.26 (from inference-sdk)
#   Downloading supervision-0.27.0.post2-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2.4.0,>=2.0.0 (from inference-sdk)
#   Downloading numpy-2.3.5-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting aiohttp~=3.13.3 (from inference-sdk)
#   Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting backoff~=2.2.0 (from inference-sdk)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting py-cpuinfo~=9.0.0 (from inference-sdk)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp~=3.13.3->inference-sdk)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp~=3.13.3->inference-sdk)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp~=3.13.3->inference-sdk)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json~=0.6.0->inference-sdk)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json~=0.6.0->inference-sdk)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging>=17.0 in ./cv2-gun/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json~=0.6.0->inference-sdk) (26.2)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.32.0->inference-sdk)
#   Using cached charset_normalizer-3.4.7-cp311-cp311-macosx_10_9_universal2.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.32.0->inference-sdk)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests<3.0.0,>=2.32.0->inference-sdk)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests<3.0.0,>=2.32.0->inference-sdk)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference-sdk)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in ./cv2-gun/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference-sdk) (4.15.0)
# Collecting scipy>=1.10.0 (from supervision>=0.26->inference-sdk)
#   Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting matplotlib>=3.6.0 (from supervision>=0.26->inference-sdk)
#   Downloading matplotlib-3.10.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting pyyaml>=5.3 (from supervision>=0.26->inference-sdk)
#   Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting defusedxml>=0.7.1 (from supervision>=0.26->inference-sdk)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting tqdm>=4.62.3 (from supervision>=0.26->inference-sdk)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting pyDeprecate<0.6.0,>=0.4.0 (from supervision>=0.26->inference-sdk)
#   Downloading pydeprecate-0.5.0-py3-none-any.whl.metadata (41 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.6.0->supervision>=0.26->inference-sdk)
#   Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.6.0->supervision>=0.26->inference-sdk)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.6.0->supervision>=0.26->inference-sdk)
#   Using cached fonttools-4.62.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.6.0->supervision>=0.26->inference-sdk)
#   Downloading kiwisolver-1.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.6.0->supervision>=0.26->inference-sdk)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./cv2-gun/lib/python3.11/site-packages (from matplotlib>=3.6.0->supervision>=0.26->inference-sdk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./cv2-gun/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision>=0.26->inference-sdk) (1.17.0)
# Downloading inference_sdk-1.2.6-py3-none-any.whl (73 kB)
# Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl (501 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Downloading numpy-2.3.5-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 48.3 MB/s  0:00:00
# Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 52.9 MB/s  0:00:01m0:00:0100:01
# Downloading pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 28.5 MB/s  0:00:00
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp311-cp311-macosx_10_9_universal2.whl (309 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl (85 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
# Downloading supervision-0.27.0.post2-py3-none-any.whl (217 kB)
# Downloading pydeprecate-0.5.0-py3-none-any.whl (38 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading matplotlib-3.10.9-cp311-cp311-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 36.5 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp311-cp311-macosx_10_9_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 51.3 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 51.4 MB/s  0:00:00 eta 0:00:01
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: py-cpuinfo, urllib3, tqdm, pyyaml, pyparsing, pyDeprecate, propcache, pillow, numpy, mypy-extensions, multidict, marshmallow, kiwisolver, idna, frozenlist, fonttools, defusedxml, cycler, charset_normalizer, certifi, backoff, attrs, aiohappyeyeballs, yarl, typing-inspect, scipy, requests, opencv-python, contourpy, aiosignal, matplotlib, dataclasses-json, aiohttp, supervision, inference-sdk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35/35 [inference-sdk]0m [aiohttp]ib]on]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 attrs-26.1.0 backoff-2.2.1 certifi-2026.4.22 charset_normalizer-3.4.7 contourpy-1.3.3 cycler-0.12.1 dataclasses-json-0.6.7 defusedxml-0.7.1 fonttools-4.62.1 frozenlist-1.8.0 idna-3.13 inference-sdk-1.2.6 kiwisolver-1.5.0 marshmallow-3.26.2 matplotlib-3.10.9 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.3.5 opencv-python-4.10.0.84 pillow-11.3.0 propcache-0.4.1 py-cpuinfo-9.0.0 pyDeprecate-0.5.0 pyparsing-3.3.2 pyyaml-6.0.3 requests-2.33.1 scipy-1.17.1 supervision-0.27.0.post2 tqdm-4.67.3 typing-inspect-0.9.0 urllib3-2.6.3 yarl-1.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from inference_sdk import InferenceHTTPClient

CLIENT = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="BbgTrEnq95LA9drZNK2f"
)

result = CLIENT.infer(your_image.jpg, model_id="people-detection-general/7")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from inference_sdk import InferenceHTTPClient
#       2
#       3 CLIENT = InferenceHTTPClient(
#       4     api_url="https://serverless.roboflow.com",
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/inference_sdk/__init__.py:5
#       2 import warnings
#       4 from inference_sdk.config import InferenceSDKDeprecationWarning
# ----> 5 from inference_sdk.http.client import InferenceHTTPClient
#       6 from inference_sdk.http.entities import (
#       7     InferenceConfiguration,
#       8     VisualisationResponseFormat,
#       9 )
#      10 from inference_sdk.utils.environment import str2bool
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/inference_sdk/http/client.py:16
#      14 import aiohttp
#      15 import numpy as np
# ---> 16 import requests
#      17 from aiohttp import ClientConnectionError, ClientResponseError
#      18 from requests import HTTPError, Response
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/requests/__init__.py:45
#      41 import warnings
#      43 import urllib3
# ---> 45 from .exceptions import RequestsDependencyWarning
#      47 try:
#      48     from charset_normalizer import __version__ as charset_normalizer_version
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/requests/exceptions.py:10
#       1 """
#       2 requests.exceptions
#       3 ~~~~~~~~~~~~~~~~~~~
#       4
#       5 This module contains the set of Requests' exceptions.
#       6 """
#       8 from urllib3.exceptions import HTTPError as BaseHTTPError
# ---> 10 from .compat import JSONDecodeError as CompatJSONDecodeError
#      13 class RequestException(IOError):
#      14     """There was an ambiguous exception that occurred while handling your
#      15     request.
#      16     """
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/requests/compat.py:42
#      38                 pass
#      39     return chardet
# ---> 42 chardet = _resolve_char_detection()
#      44 # -------
#      45 # Pythons
#      46 # -------
#      47
#      48 # Syntax sugar.
#      49 _ver = sys.version_info
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/requests/compat.py:36, in _resolve_char_detection()
#      34 if chardet is None:
#      35     try:
# ---> 36         chardet = importlib.import_module(lib)
#      37     except ImportError:
#      38         pass
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_2/Frameworks/Python.framework/Versions/3.11/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/charset_normalizer/__init__.py:26
#      22 from __future__ import annotations
#      24 import logging
# ---> 26 from .api import from_bytes, from_fp, from_path, is_binary
#      27 from .legacy import detect
#      28 from .models import CharsetMatch, CharsetMatches
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/charset_normalizer/api.py:47
#      45 for _supported_enc in IANA_SUPPORTED:
#      46     try:
# ---> 47         if is_multi_byte_encoding(_supported_enc):
#      48             _mb_supported.append(_supported_enc)
#      49         else:
#
# File ~/INSPER/7_PERIODO/computer-vision/cv-gun-detection/cv2-gun/lib/python3.11/site-packages/charset_normalizer/utils.py:281, in is_multi_byte_encoding(name)
#     265 @lru_cache(maxsize=128)
#     266 def is_multi_byte_encoding(name: str) -> bool:
#     267     """
#     268     Verify is a specific encoding is a multi byte one based on it IANA name
#     269     """
#     270     return name in {
#     271         "utf_8",
#     272         "utf_8_sig",
#     273         "utf_16",
#     274         "utf_16_be",
#     275         "utf_16_le",
#     276         "utf_32",
#     277         "utf_32_le",
#     278         "utf_32_be",
#     279         "utf_7",
#     280     } or issubclass(
# --> 281         importlib.import_module(f"encodings.{name}").IncrementalDecoder,
#     282         MultibyteIncrementalDecoder,
#     283     )
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_2/Frameworks/Python.framework/Versions/3.11/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_2/Frameworks/Python.framework/Versions/3.11/lib/python3.11/encodings/cp932.py:7
#       1 #
#       2 # cp932.py: Python Unicode Codec for CP932
#       3 #
#       4 # Written by Hye-Shik Chang <perky@FreeBSD.org>
#       5 #
# ----> 7 import _codecs_jp, codecs
#       8 import _multibytecodec as mbc
#      10 codec = _codecs_jp.getcodec('cp932')
#
# KeyboardInterrupt:
